# %% [markdown]
# <a href="https://colab.research.google.com/github/durgeshM-ai/Data-Science-Projects/blob/master/notebooks/06_normflow/01_realnvp/realnvp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌀 RealNVP

# %% [markdown]
# In this notebook, we'll walk through the steps required to train your own RealNVP network to predict the distribution of a demo dataset

# %% [markdown]
# The code has been adapted from the excellent [RealNVP tutorial](https://keras.io/examples/generative/real_nvp) created by Mandolini Giorgio Maria, Sanna Daniele and Zannini Quirini Giorgio available on the Keras website.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

from sklearn import datasets

import tensorflow as tf
from tensorflow.keras import (
    layers,
    models,
    regularizers,
    metrics,
    optimizers,
    callbacks,
)
import tensorflow_probability as tfp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 0. Parameters <a name="parameters"></a>

# %%
COUPLING_DIM = 256
COUPLING_LAYERS = 2
INPUT_DIM = 2
REGULARIZATION = 0.01
BATCH_SIZE = 256
EPOCHS = 300

# %%
# Load the data
data = datasets.make_moons(30000, noise=0.05)[0].astype("float32")
norm = layers.Normalization()
norm.adapt(data)
normalized_data = norm(data)
plt.scatter(
    normalized_data.numpy()[:, 0], normalized_data.numpy()[:, 1], c="green"
)
plt.show()

# %% [markdown]
# ## 2. Build the RealNVP network <a name="build"></a>

# %%
def Coupling(input_dim, coupling_dim, reg):
    input_layer = layers.Input(shape=(input_dim,)) # Changed to pass input_dim as a tuple

    s_layer_1 = layers.Dense(
        coupling_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(input_layer)
    s_layer_2 = layers.Dense(
        coupling_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(s_layer_1)
    s_layer_3 = layers.Dense(
        coupling_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(s_layer_2)
    s_layer_4 = layers.Dense(
        coupling_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(s_layer_3)
    s_layer_5 = layers.Dense(
        input_dim, activation="tanh", kernel_regularizer=regularizers.l2(reg)
    )(s_layer_4)

    t_layer_1 = layers.Dense(
        coupling_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(input_layer)
    t_layer_2 = layers.Dense(
        coupling_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(t_layer_1)
    t_layer_3 = layers.Dense(
        coupling_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(t_layer_2)
    t_layer_4 = layers.Dense(
        coupling_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(t_layer_3)
    t_layer_5 = layers.Dense(
        input_dim, activation="linear", kernel_regularizer=regularizers.l2(reg)
    )(t_layer_4)

    return models.Model(inputs=input_layer, outputs=[s_layer_5, t_layer_5])

# %%
class RealNVP(models.Model):
    def __init__(
        self, input_dim, coupling_layers, coupling_dim, regularization
    ):
        super(RealNVP, self).__init__()
        self.coupling_layers = coupling_layers
        self.distribution = tfp.distributions.MultivariateNormalDiag(
            loc=[0.0, 0.0], scale_diag=[1.0, 1.0]
        )
        self.masks = np.array(
            [[0, 1], [1, 0]] * (coupling_layers // 2), dtype="float32"
        )
        self.loss_tracker = metrics.Mean(name="loss")
        self.layers_list = [
            Coupling(input_dim, coupling_dim, regularization)
            for i in range(coupling_layers)
        ]

    @property
    def metrics(self):
        return [self.loss_tracker]

    def call(self, x, training=True):
        log_det_inv = 0
        direction = 1
        if training:
            direction = -1
        for i in range(self.coupling_layers)[::direction]:
            x_masked = x * self.masks[i]
            reversed_mask = 1 - self.masks[i]
            s, t = self.layers_list[i](x_masked)
            s *= reversed_mask
            t *= reversed_mask
            gate = (direction - 1) / 2
            x = (
                reversed_mask
                * (x * tf.exp(direction * s) + direction * t * tf.exp(gate * s))
                + x_masked
            )
            log_det_inv += gate * tf.reduce_sum(s, axis=1)
        return x, log_det_inv

    def log_loss(self, x):
        y, logdet = self(x)
        log_likelihood = self.distribution.log_prob(y) + logdet
        return -tf.reduce_mean(log_likelihood)

    def train_step(self, data):
        with tf.GradientTape() as tape:
            loss = self.log_loss(data)
        g = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(g, self.trainable_variables))
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

    def test_step(self, data):
        loss = self.log_loss(data)
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}


model = RealNVP(
    input_dim=INPUT_DIM,
    coupling_layers=COUPLING_LAYERS,
    coupling_dim=COUPLING_DIM,
    regularization=REGULARIZATION,
)

# %% [markdown]
# ## 3. Train the RealNVP network <a name="train"></a>

# %%
# Compile and train the model
model.compile(optimizer=optimizers.Adam(learning_rate=0.0001))

# %%
import os

# Compile and train the model
model.compile(optimizer=optimizers.Adam(learning_rate=0.0001))

# Create the output directory if it doesn't exist
output_dir = "./output"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")


class ImageGenerator(callbacks.Callback):
    def __init__(self, num_samples):
        self.num_samples = num_samples

    def generate(self):
        # From data to latent space.
        z, _ = model(normalized_data)

        # From latent space to data.
        samples = model.distribution.sample(self.num_samples)
        x, _ = model.predict(samples, verbose=0)

        return x, z, samples

    def display(self, x, z, samples, save_to=None):
        f, axes = plt.subplots(2, 2)
        f.set_size_inches(8, 5)

        axes[0, 0].scatter(
            normalized_data[:, 0], normalized_data[:, 1], color="r", s=1
        )
        axes[0, 0].set(title="Data space X", xlabel="x_1", ylabel="x_2")
        axes[0, 0].set_xlim([-2, 2])
        axes[0, 0].set_ylim([-2, 2])
        axes[0, 1].scatter(z[:, 0], z[:, 1], color="r", s=1)
        axes[0, 1].set(title="f(X)", xlabel="z_1", ylabel="z_2")
        axes[0, 1].set_xlim([-2, 2])
        axes[0, 1].set_ylim([-2, 2])
        axes[1, 0].scatter(samples[:, 0], samples[:, 1], color="g", s=1)
        axes[1, 0].set(title="Latent space Z", xlabel="z_1", ylabel="z_2")
        axes[1, 0].set_xlim([-2, 2])
        axes[1, 0].set_ylim([-2, 2])
        axes[1, 1].scatter(x[:, 0], x[:, 1], color="g", s=1)
        axes[1, 1].set(title="g(Z)", xlabel="x_1", ylabel="x_2")
        axes[1, 1].set_xlim([-2, 2])
        axes[1, 1].set_ylim([-2, 2])

        plt.subplots_adjust(wspace=0.3, hspace=0.6)
        if save_to:
            plt.savefig(save_to)
            print(f"\nSaved to {save_to}")

        plt.show()

    def on_epoch_end(self, epoch, logs=None):
        if epoch % 10 == 0:
            x, z, samples = self.generate()
            self.display(
                x,
                z,
                samples,
                save_to="./output/generated_img_%03d.png" % (epoch),
            )


img_generator_callback = ImageGenerator(num_samples=3000)

# %%
model.fit(
    normalized_data,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=[tensorboard_callback, img_generator_callback],
)
# Out:
# Epoch 1/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.3680
# Saved to ./output/generated_img_000.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - loss: 2.3675
# Epoch 2/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 2.2441
# Epoch 3/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 2.1160
# Epoch 4/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 2.0625
# Epoch 5/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 2.0112
# Epoch 6/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.9529
# Epoch 7/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.8462
# Epoch 8/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 1.7755
# Epoch 9/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 1.7589
# Epoch 10/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 1.7523
# Epoch 11/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.7564
# Saved to ./output/generated_img_010.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 1.7564
# Epoch 12/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.7485
# Epoch 13/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 1.7490
# Epoch 14/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 1.7447
# Epoch 15/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.7468
# Epoch 16/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 1.7463
# Epoch 17/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 1.7479
# Epoch 18/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.7481
# Epoch 19/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7409
# Epoch 20/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 1.7401
# Epoch 21/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.7298
# Saved to ./output/generated_img_020.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss: 1.7299
# Epoch 22/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7426
# Epoch 23/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 1.7318
# Epoch 24/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 1.7384
# Epoch 25/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.7333
# Epoch 26/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.7513
# Epoch 27/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.7376
# Epoch 28/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.7337
# Epoch 29/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7286
# Epoch 30/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.7288
# Epoch 31/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.7223
# Saved to ./output/generated_img_030.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 1.7224
# Epoch 32/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.7329
# Epoch 33/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 1.7268
# Epoch 34/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.7279
# Epoch 35/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.7271
# Epoch 36/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.7309
# Epoch 37/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 1.7455
# Epoch 38/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.7302
# Epoch 39/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 1.7353
# Epoch 40/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.7221
# Epoch 41/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.7284
# Saved to ./output/generated_img_040.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 1.7283
# Epoch 42/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.7367
# Epoch 43/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.7415
# Epoch 44/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 1.7240
# Epoch 45/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.7419
# Epoch 46/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.7398
# Epoch 47/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.7293
# Epoch 48/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 1.7257
# Epoch 49/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.7264
# Epoch 50/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 1.7401
# Epoch 51/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.7284
# Saved to ./output/generated_img_050.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 1.7284
# Epoch 52/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 1.7211
# Epoch 53/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.7127
# Epoch 54/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 1.7305
# Epoch 55/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 1.7195
# Epoch 56/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.7225
# Epoch 57/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.7281
# Epoch 58/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7440
# Epoch 59/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.7372
# Epoch 60/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.7314
# Epoch 61/300
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.7215
# Saved to ./output/generated_img_060.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 1.7215
# Epoch 62/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.7193
# Epoch 63/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.7207
# Epoch 64/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 1.7141
# Epoch 65/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.7384
# Epoch 66/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.8003
# Epoch 67/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.7373
# Epoch 68/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 1.7229
# Epoch 69/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7253
# Epoch 70/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 1.7274
# Epoch 71/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.7253
# Saved to ./output/generated_img_070.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 1.7252
# Epoch 72/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - loss: 1.7178
# Epoch 73/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.7156
# Epoch 74/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.7168
# Epoch 75/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 1.7263
# Epoch 76/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 1.7277
# Epoch 77/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.7154
# Epoch 78/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.7147
# Epoch 79/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.7146
# Epoch 80/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.7201
# Epoch 81/300
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.7137
# Saved to ./output/generated_img_080.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 1.7139
# Epoch 82/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7291
# Epoch 83/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.7138
# Epoch 84/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.7183
# Epoch 85/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.7323
# Epoch 86/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.7180
# Epoch 87/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.7229
# Epoch 88/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.7119
# Epoch 89/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.7151
# Epoch 90/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7134
# Epoch 91/300
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.7221
# Saved to ./output/generated_img_090.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 1.7220
# Epoch 92/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.7251
# Epoch 93/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 1.7087
# Epoch 94/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.7297
# Epoch 95/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7205
# Epoch 96/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7186
# Epoch 97/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.7189
# Epoch 98/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7147
# Epoch 99/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.7172
# Epoch 100/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 1.7253
# Epoch 101/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.7148
# Saved to ./output/generated_img_100.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 1.7148
# Epoch 102/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7163
# Epoch 103/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.7153
# Epoch 104/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.7259
# Epoch 105/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.7170
# Epoch 106/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.7288
# Epoch 107/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.7202
# Epoch 108/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.7164
# Epoch 109/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.7165
# Epoch 110/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 1.7125
# Epoch 111/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.7257
# Saved to ./output/generated_img_110.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 1.7258
# Epoch 112/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7143
# Epoch 113/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7296
# Epoch 114/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7215
# Epoch 115/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7240
# Epoch 116/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7091
# Epoch 117/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7266
# Epoch 118/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7172
# Epoch 119/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7213
# Epoch 120/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.7031
# Epoch 121/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.7121
# Saved to ./output/generated_img_120.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - loss: 1.7121
# Epoch 122/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7034
# Epoch 123/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 1.7020
# Epoch 124/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7158
# Epoch 125/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7087
# Epoch 126/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.7207
# Epoch 127/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7110
# Epoch 128/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7212
# Epoch 129/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.7123
# Epoch 130/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7100
# Epoch 131/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.7180
# Saved to ./output/generated_img_130.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 1.7180
# Epoch 132/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 1.7198
# Epoch 133/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7364
# Epoch 134/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7129
# Epoch 135/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7030
# Epoch 136/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7202
# Epoch 137/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7158
# Epoch 138/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7125
# Epoch 139/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 1.7098
# Epoch 140/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7205
# Epoch 141/300
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.7165
# Saved to ./output/generated_img_140.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - loss: 1.7164
# Epoch 142/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - loss: 1.7210
# Epoch 143/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7133
# Epoch 144/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7135
# Epoch 145/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.7139
# Epoch 146/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7067
# Epoch 147/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7109
# Epoch 148/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7247
# Epoch 149/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7226
# Epoch 150/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7122
# Epoch 151/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.7207
# Saved to ./output/generated_img_150.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 1.7206
# Epoch 152/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7081
# Epoch 153/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7093
# Epoch 154/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7213
# Epoch 155/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7065
# Epoch 156/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7207
# Epoch 157/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7134
# Epoch 158/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7091
# Epoch 159/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7170
# Epoch 160/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.7122
# Epoch 161/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.7150
# Saved to ./output/generated_img_160.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 1.7149
# Epoch 162/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.7130
# Epoch 163/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7073
# Epoch 164/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7133
# Epoch 165/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.7075
# Epoch 166/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.7193
# Epoch 167/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7126
# Epoch 168/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7111
# Epoch 169/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7109
# Epoch 170/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7113
# Epoch 171/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.7153
# Saved to ./output/generated_img_170.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 1.7153
# Epoch 172/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.7146
# Epoch 173/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7156
# Epoch 174/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.7133
# Epoch 175/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 1.7242
# Epoch 176/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7093
# Epoch 177/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7153
# Epoch 178/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 1.7149
# Epoch 179/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - loss: 1.7026
# Epoch 180/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - loss: 1.7186
# Epoch 181/300
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.7352
# Saved to ./output/generated_img_180.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - loss: 1.7347
# Epoch 182/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7179
# Epoch 183/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 1.7156
# Epoch 184/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.7118
# Epoch 185/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 1.7085
# Epoch 186/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.7205
# Epoch 187/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.7165
# Epoch 188/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 1.7135
# Epoch 189/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.7144
# Epoch 190/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.7190
# Epoch 191/300
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.7149
# Saved to ./output/generated_img_190.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - loss: 1.7148
# Epoch 192/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.7110
# Epoch 193/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 1.7072
# Epoch 194/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.7128
# Epoch 195/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.7108
# Epoch 196/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 1.7099
# Epoch 197/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.7155
# Epoch 198/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 1.7057
# Epoch 199/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.7080
# Epoch 200/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.7241
# Epoch 201/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.7152
# Saved to ./output/generated_img_200.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - loss: 1.7151
# Epoch 202/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.7197
# Epoch 203/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 1.7183
# Epoch 204/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.7167
# Epoch 205/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7114
# Epoch 206/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 1.7175
# Epoch 207/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.7135
# Epoch 208/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 1.7119
# Epoch 209/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.7099
# Epoch 210/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.7075
# Epoch 211/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.7110
# Saved to ./output/generated_img_210.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - loss: 1.7110
# Epoch 212/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7231
# Epoch 213/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 1.7056
# Epoch 214/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.7192
# Epoch 215/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 1.7237
# Epoch 216/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.7151
# Epoch 217/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.7129
# Epoch 218/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 1.7059
# Epoch 219/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7224
# Epoch 220/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.7083
# Epoch 221/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.7080
# Saved to ./output/generated_img_220.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - loss: 1.7080
# Epoch 222/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 1.7173
# Epoch 223/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 1.7174
# Epoch 224/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.7286
# Epoch 225/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 1.7164
# Epoch 226/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 1.7143
# Epoch 227/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 1.7152
# Epoch 228/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.7048
# Epoch 229/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7086
# Epoch 230/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7078
# Epoch 231/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.7161
# Saved to ./output/generated_img_230.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - loss: 1.7160
# Epoch 232/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.7122
# Epoch 233/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 1.7108
# Epoch 234/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 1.7072
# Epoch 235/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7069
# Epoch 236/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 1.7140
# Epoch 237/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7067
# Epoch 238/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 1.7288
# Epoch 239/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 1.7198
# Epoch 240/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7080
# Epoch 241/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.7074
# Saved to ./output/generated_img_240.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - loss: 1.7075
# Epoch 242/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 1.7106
# Epoch 243/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 1.7172
# Epoch 244/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 1.7095
# Epoch 245/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - loss: 1.7057
# Epoch 246/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 1.6991
# Epoch 247/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 1.7138
# Epoch 248/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 1.7080
# Epoch 249/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.7238
# Epoch 250/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 1.7117
# Epoch 251/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.7147
# Saved to ./output/generated_img_250.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 1.7146
# Epoch 252/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - loss: 1.7003
# Epoch 253/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 1.7126
# Epoch 254/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.7223
# Epoch 255/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 1.7066
# Epoch 256/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 1.7160
# Epoch 257/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.7058
# Epoch 258/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 1.7109
# Epoch 259/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 1.7057
# Epoch 260/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 1.7095
# Epoch 261/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.7129
# Saved to ./output/generated_img_260.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 1.7128
# Epoch 262/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - loss: 1.7220
# Epoch 263/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 1.7070
# Epoch 264/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 1.7215
# Epoch 265/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.7183
# Epoch 266/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 1.7108
# Epoch 267/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 1.7094
# Epoch 268/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 1.7061
# Epoch 269/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 1.7062
# Epoch 270/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 1.7041
# Epoch 271/300
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.7157
# Saved to ./output/generated_img_270.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 1.7155
# Epoch 272/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - loss: 1.7008
# Epoch 273/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 1.7085
# Epoch 274/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 1.6988
# Epoch 275/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 1.7225
# Epoch 276/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 1.7131
# Epoch 277/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.7109
# Epoch 278/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - loss: 1.7090
# Epoch 279/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.7051
# Epoch 280/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.7111
# Epoch 281/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.7113
# Saved to ./output/generated_img_280.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - loss: 1.7113
# Epoch 282/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 1.7089
# Epoch 283/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.7080
# Epoch 284/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 1.7088
# Epoch 285/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - loss: 1.7130
# Epoch 286/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.7033
# Epoch 287/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 1.7164
# Epoch 288/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 1.7190
# Epoch 289/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.7280
# Epoch 290/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 1.7184
# Epoch 291/300
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.7084
# Saved to ./output/generated_img_290.png
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - loss: 1.7084
# Epoch 292/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - loss: 1.7053
# Epoch 293/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.7113
# Epoch 294/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - loss: 1.7143
# Epoch 295/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 1.7000
# Epoch 296/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 1.7152
# Epoch 297/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 1.7028
# Epoch 298/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 1.7043
# Epoch 299/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 1.7160
# Epoch 300/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 1.7138

# %% [markdown]
# ## 4. Generate images <a name="generate"></a>

# %%
x, z, samples = img_generator_callback.generate()

# %%
img_generator_callback.display(x, z, samples)
